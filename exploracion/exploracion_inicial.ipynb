# %%
import pandas as pd
import gzip
import json
import ast

# %%
# Se crean las rutas para cada uno de los archivos para lograr su posterior subida a pandas.
ruta_games = "/content/steam_games.json.gz"
ruta_reviews = "/content/user_reviews.json.gz"
ruta_items = "/content/users_items.json.gz"

# %%
def open_json_compressed(rute):
  with gzip.open(rute,"rt",encoding = "utf-8") as file:
    content = json.load(file)
  return content

# %% [markdown]
# # Revisión del archivo de steam_games

# %%
# Se carga el archivo de steam_games a pandas.
games = pd.read_json(ruta_games, compression = "gzip", lines = True)
games # se explora el archivo en pandas.
# Out:
#               publisher                                 genres  \
# 0                  None                                   None
# 1                  None                                   None
# 2                  None                                   None
# 3                  None                                   None
# 4                  None                                   None
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444             None                                   None
#
#                         app_name                     title  \
# 0                           None                      None
# 1                           None                      None
# ...

# %%
games.info() # se obtiene información sobre nulos y cantidad de datos "válidos" (datos no-null).
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120445 entries, 0 to 120444
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24083 non-null  object
#  1   genres        28852 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         30085 non-null  object
#  4   url           32135 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31972 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30758 non-null  object
#  10  early_access  32135 non-null  float64
#  11  id            32133 non-null  float64
#  12  developer     28836 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 11.9+ MB

# %% [markdown]
# # Revisión del archivo de reviews

# %%
f =  gzip.open(ruta_reviews, "rt", encoding="utf-8")

data = []
with open(f) as file:
  for line in file.readlines():
   data.append(ast.literal_eval(line))

data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-1977821f25c9> in <cell line: 4>()
#       2
#       3 data = []
# ----> 4 with open(f) as file:
#       5   for line in file.readlines():
#       6    data.append(ast.literal_eval(line))
#
# TypeError: expected str, bytes or os.PathLike object, not TextIOWrapper

# %%
reviews = pd.read_json(ruta_reviews, compression = "gzip", lines = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-856d96847470> in <cell line: 1>()
# ----> 1 reviews = pd.read_json(ruta_reviews, compression = "gzip", lines = True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
reviews_content = open_json_compressed(ruta_reviews)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-16-d002c43bc4bd> in <cell line: 1>()
# ----> 1 reviews_content = open_json_compressed(ruta_reviews)
#
# <ipython-input-15-14b68537a8aa> in open_json_compressed(rute)
#       1 def open_json_compressed(rute):
#       2   with gzip.open(rute,"rt",encoding = "utf-8") as file:
# ----> 3     content = json.load(file)
#       4   return content
#
# /usr/lib/python3.10/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# ...

# %% [markdown]
# # Revisión Items

# %%
items = pd.read_json(ruta_items, compression = "gzip")
items
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-d543d7a399de> in <cell line: 1>()
# ----> 1 items = pd.read_json(ruta_items, compression = "gzip")
#       2 items
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
# Volver a comprimir las bases arregladas
#import json
#import gzip

#def compress_data(data):
    # Convert to JSON
#    json_data = json.dumps(data, indent=2)
    # Convert to bytes
#    encoded = json_data.encode('utf-8')
    # Compress
#    compressed = gzip.compress(encoded)
